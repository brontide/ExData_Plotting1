# %% [markdown]
# <a href="https://colab.research.google.com/github/brontide/ExData_Plotting1/blob/master/gasmeter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Using OpenCV to monitor gas meter
#
# In this notbook I will go over the steps I used to monitor my gas meters using python and OpenCV

# %%
# let's load our libraies
import cv2
import numpy as np
from math import cos, sin, radians, floor, ceil
import time
from google.colab.patches import cv2_imshow

# %%
# load the image in greyscale
img = cv2.imread('dials.jpg',0)

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=1920x1080 at 0x7EFF730FD2E8>

# %% [markdown]
# First let's setup a region of interest ROI within the image.  OpenCV allows you to reduce an image but the syntax is wierd, given x1,y2 -> x2,y2 you would use the following to crop.
#
# ```python3
# img = img[y1:y2, x1:x2]
# ```

# %%
# Cropped image

crop = img[300:740,650:1350]

cv2_imshow(crop)
# Out:
# <PIL.Image.Image image mode=L size=700x440 at 0x7EFF730FD5C0>
